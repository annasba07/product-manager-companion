# %% [markdown]
# # Web Scraping Medium articles with tags ML/DL/AI using BS & SELENIUM

# %%
#import all libraries
import urllib.request
import requests
import bs4
from bs4 import BeautifulSoup

# %%
#save the links we wanna scrape
arificial_intelligence = "https://medium.com/tag/product-management"

# %%
# !pip install selenium
from selenium import webdriver

# %% [markdown]
# ### Dynamic loading with selenium

# %%
driver = webdriver.Chrome('C:/Software Projects/chromedriver_win32/chromedriver.exe')
driver.get(arificial_intelligence)

# %% [markdown]
# ### Load the webpage that is displayed till you reach the end to collect all tagged articles

# %%
res = driver.execute_script("return document.documentElement.outerHTML")
print(res)

# %%
# !pip install BeautifulSoup4
# !pip install lxml
from bs4 import BeautifulSoup

soup = BeautifulSoup(res, 'lxml')

# %%
b = soup.find_all('div', {"class": "ke kf kg kh ki l"})
b

# %%
# get text from beautiful soup object and put it in a list



text = []
for i in b:
    text.append(i.text)

text[0]

# %%
# get href link from bs object and put in list

c = soup.find_all('a', {"class": "ae af ag ah ai aj ak al am an ao ap aq ar as"})


links = []
for i in c:
    links.append(i.get('href'))


links

# remove all items that include the word signin from links

links2 = [i for i in links if 'signin' not in i]
#links2 = [i for i in links2 if '?' not in i]

# remove all duplicates form links2

links3 = list(dict.fromkeys(links2))

# %%
print(len(links3))
print(len(text))
links3[4:503]

links4 = links3[4:503]

links4

# %%
# take the title in text and replace spaces with dashes and make it lowercase

text2 = []
for i in text:
    text2.append(i.replace(" ", "-").lower())


text2

# %%
# search links4 for the text2 and if it is in the link add it to a list

links5 = []
indicesi = []
indicesj = []

for i in text2:
    for j in links4:
        if i in j:
            links5.append(j)
            indicesi.append(text2.index(i))
            indicesj.append(links4.index(j))


links5



print(len(links5))
print(len(indicesi))
print(len(indicesj))
print(len(text2))

# %%
finaltext = [text2[i] for i in indicesi]
len(finaltext)

finallinks = links5

# %%
print(len(finallinks))
print(len(finaltext))

# %%
# add https://www.medium.com to the beginning of each item in the list

finallinks = ['https://www.medium.com' + i for i in finallinks]
finallinks

# %%
len(finallinks)
len(finaltext)

print('there are {} words and {} links'.format(len(finaltext), len(finallinks)))

# %%
print('good work!!!')

# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame({'text': finaltext, 'links': finallinks})
df

# %%
# scrape all text from each link in links4

import urllib.request
import requests
import bs4
from bs4 import BeautifulSoup

content = []
for i in finallinks:
    url = i
    response = requests.get(url)
    soup = BeautifulSoup(response.text, "html.parser")
    content.append(soup.get_text())

# %%
# add text2 to df

df['content'] = content

# %%
df['content'][0]

# add a column to df which shows the length of each article

df['content_length'] = df['content'].str.len()

df

# %%
# save df as csv

df.to_csv('product_management2.csv')

# %%
# remove rows in df where content length is less than 8000

df = df[df.content_length > 8000]

# %%
df

# %%
# !pip install openai

# !pip install pandas
# !pip install numpy
# !pip install matplotlib



import pandas as pd
import openai
import numpy as np


COMPLETIONS_MODEL = "text-embedding-ada-002"
# Out:
# Requirement already satisfied: openai in c:\users\annas\appdata\local\programs\python\python311\lib\site-packages (0.25.0)
# Requirement already satisfied: requests>=2.20 in c:\users\annas\appdata\local\programs\python\python311\lib\site-packages (from openai) (2.28.1)
# Requirement already satisfied: tqdm in c:\users\annas\appdata\local\programs\python\python311\lib\site-packages (from openai) (4.64.1)
# Requirement already satisfied: pandas>=1.2.3 in c:\users\annas\appdata\local\programs\python\python311\lib\site-packages (from openai) (1.5.2)
# Requirement already satisfied: pandas-stubs>=1.1.0.11 in c:\users\annas\appdata\local\programs\python\python311\lib\site-packages (from openai) (1.5.2.221213)
# Requirement already satisfied: openpyxl>=3.0.7 in c:\users\annas\appdata\local\programs\python\python311\lib\site-packages (from openai) (3.0.10)
# Requirement already satisfied: numpy in c:\users\annas\appdata\local\programs\python\python311\lib\site-packages (from openai) (1.23.5)
# Requirement already satisfied: typing-extensions in c:\users\annas\appdata\local\programs\python\python311\lib\site-packages (from openai) (4.4.0)
# Requirement already satisfied: et-xmlfile in c:\users\annas\appdata\local\programs\python\python311\lib\site-packages (from openpyxl>=3.0.7->openai) (1.1.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\annas\appdata\local\programs\python\python311\lib\site-packages (from pandas>=1.2.3->openai) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\annas\appdata\local\programs\python\python311\lib\site-packages (from pandas>=1.2.3->openai) (2022.6)
# Requirement already satisfied: types-pytz>=2022.1.1 in c:\users\annas\appdata\local\programs\python\python311\lib\site-packages (from pandas-stubs>=1.1.0.11->openai) (2022.7.0.0)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\annas\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.20->openai) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\annas\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.20->openai) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\annas\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.20->openai) (1.26.13)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\annas\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.20->openai) (2022.12.7)
# Requirement already satisfied: colorama in c:\users\annas\appdata\local\programs\python\python311\lib\site-packages (from tqdm->openai) (0.4.5)
# Requirement already satisfied: six>=1.5 in c:\users\annas\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil>=2.8.1->pandas>=1.2.3->openai) (1.16.0)
# Requirement already satisfied: pandas in c:\users\annas\appdata\local\programs\python\python311\lib\site-packages (1.5.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\annas\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\annas\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2022.6)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\annas\appdata\local\programs\python\python311\lib\site-packages (from pandas) (1.23.5)
# Requirement already satisfied: six>=1.5 in c:\users\annas\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Requirement already satisfied: numpy in c:\users\annas\appdata\local\programs\python\python311\lib\site-packages (1.23.5)
# Requirement already satisfied: matplotlib in c:\users\annas\appdata\local\programs\python\python311\lib\site-packages (3.6.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\annas\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (1.0.6)
# Requirement already satisfied: cycler>=0.10 in c:\users\annas\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\annas\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (4.38.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\annas\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.19 in c:\users\annas\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\annas\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\annas\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (9.3.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\annas\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\annas\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\annas\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
import os
openai.api_key = os.getenv("OPENAI_API_KEY")

# !pip install plotly
# !pip install -U scikit-learn scipy matplotlib

from openai.embeddings_utils import get_embeddings, cosine_similarity

# %%
# get data from csv and store in df
import pandas as pd


df2 = None



input_datapath = 'product_management2_with_embeddings.csv'  # to save space, we provide a pre-filtered dataset
df2 = pd.read_csv(input_datapath, index_col=0)
#df2 = df2[['Text', 'Links', 'Content', 'Content_Length', 'Embeddings']]
df2 = df2.dropna()
df2['combined'] = "Title: " + df2.text.str.strip() + "; Content: " + df2.content.str.strip()
df2 = df2[df2.content_length < 2000]
df2.head(2)
# Out:
#                                                  text  \
# 15                          past-speaking-engagements
# 17  four-pillars-of-world-class-product-documentation
#
#                                                 links  \
# 15  https://www.medium.com/@sergioschuler/past-spe...
# 17  https://www.medium.com/@sebscholl/four-pillars...
#
#                                               content  content_length  \
# 15  Past speaking engagements - Sérgio Schüler - M...            1925
# 17  Four Pillars of World-Class Product Documentat...            1464
#
#                                            embeddings  \
# 15  [-0.006651689764112234, -0.005385522730648518,...
# 17  [0.022534579038619995, 0.03746522217988968, 0....
#
#                                              combined
# 15  Title: past-speaking-engagements; Content: Pas...
# 17  Title: four-pillars-of-world-class-product-doc...

# %%
# drop embeddings from df2

df2 = df2.drop(columns=['embeddings'])

# %%
df2
# Out:
#                                                  text  \
# 15                          past-speaking-engagements
# 17  four-pillars-of-world-class-product-documentation
# 30  lack-of-courage-and-fear-of-failure-keep-the-f...
# 32  25-most-common-questions-asked-in-a-tech-produ...
# 76                     six-types-of-product-discovery
#
#                                                 links  \
# 15  https://www.medium.com/@sergioschuler/past-spe...
# 17  https://www.medium.com/@sebscholl/four-pillars...
# 30  https://www.medium.com/serious-scrum/lack-of-c...
# 32  https://www.medium.com/@smohajer85/25-most-com...
# 76  https://www.medium.com/@susan_ski/six-types-of...
#
#                                               content  content_length  \
# 15  Past speaking engagements - Sérgio Schüler - M...            1925
# 17  Four Pillars of World-Class Product Documentat...            1464
# 30  Lack of Courage And Fear of Failure Keep the F...            1626
# 32  25 most common questions asked in a tech produ...             996
# 76  Six Types of Product Discovery. “You need to d...            1649
#
#                                              combined
# 15  Title: past-speaking-engagements; Content: Pas...
# 17  Title: four-pillars-of-world-class-product-doc...
# 30  Title: lack-of-courage-and-fear-of-failure-kee...
# 32  Title: 25-most-common-questions-asked-in-a-tec...
# 76  Title: six-types-of-product-discovery; Content...

# %%
df2 = df2.content.apply(split_string).reset_index(drop=True)

# %%
df2
# Out:
#                                                  text  \
# 15                          past-speaking-engagements
# 17  four-pillars-of-world-class-product-documentation
# 30  lack-of-courage-and-fear-of-failure-keep-the-f...
# 32  25-most-common-questions-asked-in-a-tech-produ...
# 76                     six-types-of-product-discovery
#
#                                                 links  \
# 15  https://www.medium.com/@sergioschuler/past-spe...
# 17  https://www.medium.com/@sebscholl/four-pillars...
# 30  https://www.medium.com/serious-scrum/lack-of-c...
# 32  https://www.medium.com/@smohajer85/25-most-com...
# 76  https://www.medium.com/@susan_ski/six-types-of...
#
#                                               content  content_length  \
# 15  Past speaking engagements - Sérgio Schüler - M...            1925
# 17  Four Pillars of World-Class Product Documentat...            1464
# 30  Lack of Courage And Fear of Failure Keep the F...            1626
# 32  25 most common questions asked in a tech produ...             996
# 76  Six Types of Product Discovery. “You need to d...            1649
#
#                                              combined
# 15  Title: past-speaking-engagements; Content: Pas...
# 17  Title: four-pillars-of-world-class-product-doc...
# 30  Title: lack-of-courage-and-fear-of-failure-kee...
# 32  Title: 25-most-common-questions-asked-in-a-tec...
# 76  Title: six-types-of-product-discovery; Content...

# %%
# get embeddings for each article in df and store in a new column

df2["embeddings"] = df2.combined.apply(lambda x: get_embedding(x, engine='text-embedding-ada-002'))

# %%
embeddingtest = get_embedding(
        df2.combined[15],
        engine="text-embedding-ada-002"
    )

# %%
df2
# Out:
#                                                  text  \
# 15                          past-speaking-engagements
# 17  four-pillars-of-world-class-product-documentation
# 30  lack-of-courage-and-fear-of-failure-keep-the-f...
# 32  25-most-common-questions-asked-in-a-tech-produ...
# 76                     six-types-of-product-discovery
#
#                                                 links  \
# 15  https://www.medium.com/@sergioschuler/past-spe...
# 17  https://www.medium.com/@sebscholl/four-pillars...
# 30  https://www.medium.com/serious-scrum/lack-of-c...
# 32  https://www.medium.com/@smohajer85/25-most-com...
# 76  https://www.medium.com/@susan_ski/six-types-of...
#
#                                               content  content_length  \
# 15  Past speaking engagements - Sérgio Schüler - M...            1925
# 17  Four Pillars of World-Class Product Documentat...            1464
# 30  Lack of Courage And Fear of Failure Keep the F...            1626
# 32  25 most common questions asked in a tech produ...             996
# 76  Six Types of Product Discovery. “You need to d...            1649
#
#                                              combined  \
# 15  Title: past-speaking-engagements; Content: Pas...
# 17  Title: four-pillars-of-world-class-product-doc...
# 30  Title: lack-of-courage-and-fear-of-failure-kee...
# 32  Title: 25-most-common-questions-asked-in-a-tec...
# 76  Title: six-types-of-product-discovery; Content...
#
#                                            embeddings
# 15  [-0.01302818488329649, -0.0026764797512441874,...
# 17  [0.02161411941051483, 0.038200464099645615, 0....
# 30  [-0.02281850576400757, -0.007446258328855038, ...
# 32  [0.013337370939552784, -0.013675819151103497, ...
# 76  [0.0038728078361600637, 0.020918523892760277, ...

# %%
# get embeddings for each article in df2 and store in a new column, do not use apply



for index, row in df2.iterrows():
    embeddings = get_embeddings(row['combined'], engine='text-embedding-ada-002')
    print(embeddings)
    df2.at[index, 'embeddings'] = embeddings

# %%
df2

# %%
embeddingpm = get_embeddings(
        "which coffee is best?",
        engine="text-embedding-ada-002"
    )

# %%
df2['embeddings'][15]

shape = [len(sublist) for sublist in df2['embeddings']]
shape

# %%
similarityvector = np.dot(np.array(embeddingpm), np.array(df2["embeddings"][15]))

# %%
df2["similarities"] = df2.embeddings.apply(lambda x: np.dot(np.array(embeddingpm), np.array(x)))

# %%
df['ada_similarity'] = df.combined.apply(lambda x: get_embedding(x, engine='text-embedding-ada-002'))

# %%
# save df as csv

df2.to_csv('product_management2_with_embeddings_fixed.csv')

# %%
import numpy as np

df2["ada_search"] = df2.embeddings.apply(np.array)

# %%
# Check the data type of the 'similarities' column
df2.similarities.dtype
# Convert the 'similarities' column to a numeric data type
df2.similarities = df2.similarities.apply(lambda x: pd.to_numeric(x, errors='coerce'))
df2.similarities = pd.to_numeric(df2.similarities, errors='coerce')


df2.sort_values("similarities", ascending=False).head(1)

# %%
from openai.embeddings_utils import get_embedding, cosine_similarity


def search_content(df2, query, n=3, pprint=True):
    embedding = get_embedding(
        query,
        engine="text-embedding-ada-002"
    )
    df2["similarities"] = df2.ada_search.apply(lambda x: cosine_similarity(x, embedding))

    res = (
        df2.sort_values("similarities", ascending=False)
        .head(n)
    )
   
    if pprint:
        for r in res:
            print(r[:200])
            print()
    return res


res = search_content(df2, "product", n=2)

# %%
# search articles based on query

def search_articles(df2, query, n=3, pprint=True):
   embedding = get_embeddings(query, engine='text-embedding-ada-002')
   df2['similarities'] = df2.embeddings.apply(lambda x: cosine_similarity(x, embedding))
   res = df2.sort_values('similarities', ascending=False).head(n)
   return res

# %%
# use the search

result = search_articles(df2, "what is product management?", n=3)

# %%
df2

# %%
# testing open ai tutorial

import pandas as pd

input_datapath = 'Reviews.csv'  # to save space, we provide a pre-filtered dataset
df = pd.read_csv(input_datapath, index_col=0)
df = df[['Time', 'ProductId', 'UserId', 'Score', 'Summary', 'Text']]
df = df.dropna()
df['combined'] = "Title: " + df.Summary.str.strip() + "; Content: " + df.Text.str.strip()
df.head(2)

# %%
# !pip install transformers

# %%
# subsample to 1k most recent reviews and remove samples that are too long

df["combinedlength"] = df['combined'].str.len()

# %%
df = df[df.combinedlength<2000]

# %%
df2

# %%
# sort df by combinedlength desc

df = df.sort_values('combinedlength', ascending=False)
df = df[:100]

# %%
import openai
from openai.embeddings_utils import get_embedding
# Ensure you have your API key set in your environment per the README: https://github.com/openai/openai-python#usage

# This will take just between 5 and 10 minutes
#df['ada_similarity'] = df.combined.apply(lambda x: get_embedding(x, engine='text-embedding-ada-002'))
#df['ada_search'] = df.combined.apply(lambda x: get_embedding(x, engine='text-embedding-ada-002'))

# %%
df.ada_search

# %%
# add a new column to df2 called embeddings with nothing in it

df2['embeddings'] = None

# %%
df2.embeddings[15] = get_embedding(df2.content[15], engine="text-embedding-ada-002")
# Out:
# C:\Users\annas\AppData\Local\Temp\ipykernel_16012\1757485109.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.embeddings[15] = get_embedding(df2.content[15], engine="text-embedding-ada-002")

# %%
df2.embeddings[15]
# Out:
# [-0.006783561781048775,
#  -0.00555927911773324,
#  0.0076698740012943745,
#  -0.005297178868204355,
#  0.0003530590620357543,
#  0.02099558897316456,
#  -0.002764120465144515,
#  -0.013036026619374752,
#  -0.018388384953141212,
#  -0.022830290719866753,
#  0.025851337239146233,
#  0.01729859970510006,
#  -0.008511352352797985,
#  0.010304668918251991,
#  0.0018088349606841803,
#  0.0001964672264875844,
#  0.028693053871393204,
#  -0.012049702927470207,
#  -0.0010190862230956554,
#  -0.009739084169268608,
#  -0.013477458618581295,
#  0.012187650427222252,
#  0.014049939811229706,
#  0.02273372747004032,
#  -0.010346053168177605,
#  -0.009987389668822289,
#  0.030679496005177498,
#  -0.015022468753159046,
#  -0.005866211839020252,
#  -0.007442260626703501,
#  0.030238064005970955,
#  -0.0038211422506719828,
#  0.003607323858886957,
#  -0.010090850293636322,
#  -0.010663331486284733,
#  -0.01782280020415783,
#  0.0011044411221519113,
#  0.007331902626901865,
#  0.00862171035259962,
#  -0.007035315968096256,
#  -0.018333205953240395,
#  0.015739794820547104,
#  -0.001251010224223137,
#  -0.036004263907670975,
#  -0.013987863436341286,
#  0.022954443469643593,
#  -0.02118871547281742,
#  -0.012560107745230198,
#  -0.0032021033111959696,
#  0.006935304030776024,
#  0.01184278167784214,
#  0.027037683874368668,
#  -0.034404072910547256,
#  0.011911755427718163,
#  0.0035797343589365482,
#  -0.00634557893499732,
#  -2.7293102903058752e-05,
#  0.03294183313846588,
#  0.01924365758895874,
#  -0.022982031106948853,
#  0.01652609556913376,
#  -0.008283739909529686,
#  -0.014677600003778934,
#  -0.00771815562620759,
#  0.0006009332137182355,
#  -0.005679983180016279,
#  -0.035231757909059525,
#  -0.011449632234871387,
#  -0.008932092227041721,
#  0.01027018204331398,
#  0.025603031739592552,
#  0.024623606353998184,
#  -0.012470442801713943,
#  -0.013201563619077206,
#  0.048557475209236145,
#  -0.013925787061452866,
#  -0.0010828868253156543,
#  0.015588052570819855,
#  0.011070276610553265,
#  -0.006962893530726433,
#  0.010635741986334324,
#  -0.013001539744436741,
#  -0.003271077061071992,
#  -0.0034141973592340946,
#  0.008821734227240086,
#  0.03561801090836525,
#  0.0001817025477066636,
#  0.029410379007458687,
#  -0.025616826489567757,
#  -0.0032417632173746824,
#  0.010290874168276787,
#  0.014732779003679752,
#  0.018360795453190804,
#  0.013960273936390877,
#  -0.014429295435547829,
#  0.017933158203959465,
#  -0.006655960809439421,
#  0.02149219997227192,
#  -0.009966697543859482,
#  -0.011587578803300858,
#  -0.0251340102404356,
#  0.007945768535137177,
#  -0.01594671607017517,
#  -0.01809869520366192,
#  -0.045439865440130234,
#  0.005942082963883877,
#  0.005900698713958263,
#  0.0007513820892199874,
#  0.016332969069480896,
#  -0.009456292726099491,
#  -0.004362585488706827,
#  0.022306090220808983,
#  0.0026641085278242826,
#  -0.02683076448738575,
#  -0.011601373553276062,
#  -0.016939938068389893,
#  0.019174683839082718,
#  -0.0037763093132525682,
#  -0.006073133088648319,
#  -0.014387911185622215,
#  0.057993073016405106,
#  -0.0111806346103549,
#  0.02038862183690071,
#  -0.03382469713687897,
#  0.02056795358657837,
#  0.028996536508202553,
#  -0.013311921618878841,
#  -0.020374827086925507,
#  0.008814836852252483,
#  -0.01769864745438099,
#  0.0015269049908965826,
#  0.010028773918747902,
#  -0.004048755392432213,
#  -0.014346526935696602,
#  0.007780231535434723,
#  0.007290518376976252,
#  -0.027837779372930527,
#  0.0005474786157719791,
#  -0.019933395087718964,
#  -0.04052893817424774,
#  0.014856931753456593,
#  0.014429295435547829,
#  -0.003955640830099583,
#  -0.01705029420554638,
#  0.004231535829603672,
#  0.03192102164030075,
#  0.022499216720461845,
#  -0.005359255243092775,
#  -0.0007393116829916835,
#  -0.0008345816168002784,
#  0.016512300819158554,
#  -0.0023037211503833532,
#  -0.006742177996784449,
#  0.0033745374530553818,
#  0.008207868784666061,
#  0.004207395017147064,
#  0.01729859970510006,
#  0.010573665611445904,
#  -0.03490068390965462,
#  -0.005331665743142366,
#  0.004707454238086939,
#  0.023644179105758667,
#  -0.02076108008623123,
#  0.009856339544057846,
#  0.005548933055251837,
#  0.021602557972073555,
#  0.026899738237261772,
#  0.019850626587867737,
#  0.021754300221800804,
#  -0.00039702976937405765,
#  -0.03227968513965607,
#  0.019354015588760376,
#  -0.039701253175735474,
#  0.029796632006764412,
#  0.0038073475006967783,
#  0.00829753465950489,
#  -0.01105648186057806,
#  0.001955403946340084,
#  -0.028417158871889114,
#  -0.034983452409505844,
#  0.00018547454965300858,
#  -0.02448565885424614,
#  0.027644652873277664,
#  0.025837542489171028,
#  -0.022802701219916344,
#  -0.0031003672629594803,
#  0.007766436785459518,
#  -0.0052454485557973385,
#  -0.002481328323483467,
#  -0.013229153119027615,
#  -0.0003241763333790004,
#  0.009594239294528961,
#  -0.02371315285563469,
#  -0.0163467638194561,
#  -0.6369857788085938,
#  -0.01427755318582058,
#  0.010552973486483097,
#  -0.00074405362829566,
#  0.019381605088710785,
#  0.003621118376031518,
#  -0.004562609363347292,
#  0.016277790069580078,
#  -0.032886654138565063,
#  -0.001964025665074587,
#  0.0039797816425561905,
#  0.01156688667833805,
#  -0.01757449470460415,
#  -0.002634794684126973,
#  -0.007752642035484314,
#  -0.011863473802804947,
#  0.012463545426726341,
#  -0.02960350550711155,
#  -0.001564840436913073,
#  0.0065628462471067905,
#  -0.01387750543653965,
#  0.009766673669219017,
#  0.0189677644520998,
#  0.002869305433705449,
#  -0.0035159336403012276,
#  -0.01153239980340004,
#  0.008952784352004528,
#  -0.01684337481856346,
#  -0.00288309995085001,
#  0.01662265881896019,
#  -0.028913769870996475,
#  0.014732779003679752,
#  0.013580918312072754,
#  -0.006566294934600592,
#  0.05575832724571228,
#  -0.002091627102345228,
#  -2.4181204025808256e-06,
#  0.026941122487187386,
#  0.016677837818861008,
#  0.040170274674892426,
#  -0.01869186945259571,
#  -0.0052351029589772224,
#  0.0006798218819312751,
#  0.010766792111098766,
#  -0.0083251241594553,
#  0.004810914397239685,
#  0.01964370533823967,
#  0.004455700051039457,
#  -0.0032538336236029863,
#  -0.0028089534025639296,
#  -0.003959089517593384,
#  -0.023257926106452942,
#  -0.03536970540881157,
#  0.0016182950930669904,
#  0.0013458490138873458,
#  -0.0060214027762413025,
#  0.03010011650621891,
#  -0.026265179738402367,
#  -6.191465945448726e-05,
#  -0.004369482863694429,
#  0.0032917691860347986,
#  0.022775111719965935,
#  -0.011346171610057354,
#  -0.008152689784765244,
#  -0.01887120120227337,
#  0.008807939477264881,
#  -0.015863947570323944,
#  -0.017464136704802513,
#  0.026789380237460136,
#  -0.03112092614173889,
#  0.010987508110702038,
#  0.03636292740702629,
#  -0.006966342218220234,
#  -0.0008940714178606868,
#  0.004221189767122269,
#  0.032334864139556885,
#  0.011525502428412437,
#  0.006876676343381405,
#  0.003015874419361353,
#  0.0006983585772104561,
#  0.010752997361123562,
#  -0.018636690452694893,
#  -0.01714685745537281,
#  -0.008152689784765244,
#  0.0034021269530057907,
#  0.0030951942317187786,
#  -0.029189663007855415,
#  -0.015932921320199966,
#  0.014691394753754139,
#  0.03586631640791893,
#  0.016912348568439484,
#  0.018733253702521324,
#  -0.009911518543958664,
#  0.0028934460133314133,
#  -0.0005039389943704009,
#  0.01569841057062149,
#  -0.004093588329851627,
#  0.031065747141838074,
#  0.011159942485392094,
#  -0.021395636722445488,
#  0.001967474352568388,
#  0.009752878919243813,
#  5.841208985657431e-05,
#  -0.017850389704108238,
#  0.01862289570271969,
#  0.03170030564069748,
#  -0.007559516001492739,
#  -0.0021381841506808996,
#  0.022595779970288277,
#  -0.009856339544057846,
#  0.0014398256316781044,
#  -0.020899027585983276,
#  -0.0002487363526597619,
#  -0.020278263837099075,
#  -0.007773334160447121,
#  -0.021519789472222328,
#  0.019933395087718964,
#  -0.011318582110106945,
#  0.005141988396644592,
#  -0.019312631338834763,
#  0.016057074069976807,
#  0.00826304778456688,
#  0.017712442204356194,
#  -0.0036383618135005236,
#  -0.007021521218121052,
#  0.017505520954728127,
#  0.0022640612442046404,
#  -0.009635623544454575,
#  0.0169675275683403,
#  -0.015712205320596695,
#  -0.004483289550989866,
#  -0.04199117794632912,
#  0.00771815562620759,
#  -0.024389095604419708,
#  0.01887120120227337,
#  0.008904502727091312,
#  0.03536970540881157,
#  -0.013470561243593693,
#  0.0036900921259075403,
#  -0.009311447851359844,
#  -0.012070395052433014,
#  -0.010077055543661118,
#  0.0015165589284151793,
#  -0.027023889124393463,
#  -0.02495468035340309,
#  -0.01739516295492649,
#  -0.005486856680363417,
#  -0.0034693763591349125,
#  -0.010939226485788822,
#  0.0059903645887970924,
#  0.004048755392432213,
#  -0.004528122488409281,
#  0.020430006086826324,
#  0.021657736971974373,
#  0.007752642035484314,
#  -0.010904739610850811,
#  -0.007373286876827478,
#  -0.016057074069976807,
#  -0.032859064638614655,
#  -0.032859064638614655,
#  0.007214647717773914,
#  0.02189224772155285,
#  -0.034707557410001755,
#  -0.006424898747354746,
#  -0.004759184084832668,
#  -0.007711258251219988,
#  -0.01936781033873558,
#  0.005093706771731377,
#  -0.006152452901005745,
#  -0.01453965250402689,
#  0.0010139131918549538,
#  -0.0045212251134216785,
#  -0.010815073736011982,
#  -0.025244368240237236,
#  0.0012251450680196285,
#  -0.0015148345846682787,
#  0.004338444676250219,
#  0.0008626021444797516,
#  0.004234984517097473,
#  0.016181226819753647,
#  -0.006624922621995211,
#  0.0024364953860640526,
#  -0.0022330230567604303,
#  0.014263758435845375,
#  0.03244522213935852,
#  0.015919126570224762,
#  0.00320382765494287,
#  0.011346171610057354,
#  -0.01964370533823967,
#  0.036252569407224655,
#  0.004486738238483667,
#  0.023878689855337143,
#  -0.012884284369647503,
#  0.011284095235168934,
#  -0.024347711354494095,
#  0.040197864174842834,
#  -0.01478795800358057,
#  0.0008143205777741969,
#  -0.021630147472023964,
#  0.016953732818365097,
#  -0.01415340043604374,
#  0.031010568141937256,
#  0.008656197227537632,
#  -0.025327136740088463,
#  0.01569841057062149,
#  -0.018484948202967644,
#  0.006576640997081995,
#  -0.019257452338933945,
#  0.03222450613975525,
#  0.02460981160402298,
#  0.022926853969693184,
#  -0.015532873570919037,
#  -0.004897131584584713,
#  -0.028472337871789932,
#  -0.0070422133430838585,
#  0.008104408159852028,
#  0.010366745293140411,
#  -0.013373997993767262,
#  -0.010552973486483097,
#  0.013042923994362354,
#  0.004276368301361799,
#  -0.018512537702918053,
#  0.00449363561347127,
#  -0.01727101020514965,
#  -0.0240580216050148,
#  0.03429371491074562,
#  0.003828039625659585,
#  0.01856771670281887,
#  0.01199452392756939,
#  -0.002045069821178913,
#  0.0009363177814520895,
#  0.013105000369250774,
#  0.015284569002687931,
#  0.015325953252613544,
#  0.025699594989418983,
#  0.01674681156873703,
#  0.011946242302656174,
#  -0.02084384858608246,
#  0.05062668398022652,
#  -0.006242118775844574,
#  0.006493872497230768,
#  0.02593410573899746,
#  0.020361032336950302,
#  0.00048497121315449476,
#  0.014994879253208637,
#  -0.0039487434551119804,
#  0.03658364340662956,
#  -0.010987508110702038,
#  -0.031589947640895844,
#  0.009332139976322651,
#  -0.03274870663881302,
#  0.007421568501740694,
#  -0.00018202586215920746,
#  -0.01724342070519924,
#  0.022306090220808983,
#  -0.0029710414819419384,
#  -0.006352476309984922,
#  0.014008555561304092,
#  -0.011739321053028107,
#  0.01757449470460415,
#  -0.00720085296779871,
#  0.00537304999306798,
#  0.004721248988062143,
#  -0.013422279618680477,
#  0.015808768570423126,
#  -0.006145555526018143,
#  -0.00607658177614212,
#  -0.027341168373823166,
#  -0.011877268552780151,
#  -0.02106456272304058,
#  0.018484948202967644,
#  -0.019698884338140488,
#  -0.0008871740428730845,
#  0.0031314052175730467,
#  -0.00014656908751931041,
#  0.00471090292558074,
#  0.004393623676151037,
#  -0.004738492425531149,
#  0.007759539410471916,
#  0.012339392676949501,
#  -0.014318937435746193,
#  -0.024747759103775024,
#  0.02069210633635521,
#  0.0025813402608036995,
#  -0.013498149812221527,
#  -0.010877150110900402,
#  0.010587460361421108,
#  -0.01205660030245781,
#  -0.025216778740286827,
#  -0.0044625974260270596,
#  0.008400995284318924,
#  0.009725289419293404,
#  -0.020678311586380005,
#  0.00842168740928173,
#  -0.0010587461292743683,
#  0.016208816319704056,
#  0.028693053871393204,
#  -0.0012811862397938967,
#  -0.013236050494015217,
#  -0.013525739312171936,
#  -0.0024330466985702515,
#  0.0030141500756144524,
#  -0.016981322318315506,
#  0.0007604348938912153,
#  0.024913296103477478,
#  0.016457121819257736,
#  -0.0434810109436512,
#  -0.008407892659306526,
#  -0.00848376378417015,
#  0.017077883705496788,
#  0.013574020937085152,
#  0.0030089770443737507,
#  -0.033107370138168335,
#  0.009677007794380188,
#  0.03200379014015198,
#  0.015684615820646286,
#  -0.003876321017742157,
#  -0.012291111052036285,
#  0.005597214680165052,
#  0.02106456272304058,
#  -0.01453965250402689,
#  -0.0012518723960965872,
#  -0.01114614773541689,
#  0.01964370533823967,
#  0.057993073016405106,
#  0.06053130701184273,
#  -0.0025830646045506,
#  0.0009794263169169426,
#  -0.013594713062047958,
#  0.004345342051237822,
#  -0.03034842200577259,
#  -0.01989201083779335,
#  0.02408561110496521,
#  -0.0040694475173950195,
#  -0.004266022238880396,
#  -0.00753192650154233,
#  0.007545721251517534,
#  -0.021671531721949577,
#  -0.0032072763424366713,
#  -0.010339155793190002,
#  0.02930002100765705,
#  -0.007276723627001047,
#  0.0013355029514059424,
#  -0.027244605123996735,
#  -0.006755972281098366,
#  -0.014036145061254501,
#  0.006066235713660717,
#  0.03092780150473118,
#  0.028017111122608185,
#  -0.0048557473346591,
#  0.03691471740603447,
#  0.021630147472023964,
#  0.014139605686068535,
#  -0.037025075405836105,
#  -0.006242118775844574,
#  0.0194229893386364,
#  0.029272431507706642,
#  0.023382078856229782,
#  -0.014760368503630161,
#  0.015781179070472717,
#  0.012635978870093822,
#  0.024195969104766846,
#  0.00826304778456688,
#  0.021602557972073555,
#  0.017408957704901695,
#  0.01822284795343876,
#  0.018981557339429855,
#  -0.013105000369250774,
#  0.026747995987534523,
#  -0.0217405054718256,
#  -0.017877979204058647,
#  0.02420976385474205,
#  -0.00877345260232687,
#  -0.011753115803003311,
#  -0.0025071934796869755,
#  0.017077883705496788,
#  -0.01049779448658228,
#  -0.003548696171492338,
#  -0.0018709112191572785,
#  -0.00025132286828011274,
#  0.04640549421310425,
#  -0.010380540043115616,
#  -0.004114280454814434,
#  -0.008311329409480095,
#  -0.0034917928278446198,
#  -0.02738255262374878,
#  -0.006176593713462353,
#  -0.007366389501839876,
#  -0.017753826454281807,
#  -0.016153637319803238,
#  -0.013594713062047958,
#  -0.005200616084039211,
#  -0.05388224497437477,
#  0.010263284668326378,
#  -0.02158876322209835,
#  0.006897368468344212,
#  -0.0323900431394577,
#  -0.00707670021802187,
#  0.021230099722743034,
#  0.01585015282034874,
#  0.014167195186018944,
#  0.01612604781985283,
#  -0.0049730027094483376,
#  -0.0034848954528570175,
#  -0.008035434409976006,
#  -0.009794263169169426,
#  0.0019019494066014886,
#  -0.016291584819555283,
#  -0.007821615785360336,
#  0.006987034343183041,
#  -0.006331784185022116,
#  -0.003997025080025196,
#  -0.006949098780751228,
#  -0.01133237686008215,
#  -0.016553685069084167,
#  -0.009332139976322651,
#  0.0009044174803420901,
#  0.004435007926076651,
#  -0.003607323858886957,
#  0.008966579101979733,
#  0.024664990603923798,
#  0.007614695001393557,
#  0.03327290713787079,
#  -0.004786773584783077,
#  -0.007497439626604319,
#  -0.03112092614173889,
#  -0.011615168303251266,
#  -0.019312631338834763,
#  -0.0028020560275763273,
#  0.015794973820447922,
#  0.010028773918747902,
#  -0.002708941465243697,
#  -0.013649892061948776,
#  0.00625246437266469,
#  0.02698250487446785,
#  0.0015200076159089804,
#  0.023823510855436325,
#  0.017657263204455376,
#  0.0017476207576692104,
#  0.015105237253010273,
#  0.01659506931900978,
#  0.0348455049097538,
#  0.015132826752960682,
#  -0.007021521218121052,
#  0.013325716368854046,
#  -0.01807110570371151,
#  0.04612959921360016,
#  0.013580918312072754,
#  -0.030182885006070137,
#  0.010152926668524742,
#  -0.01451206300407648,
#  -0.004455700051039457,
#  -0.012856694869697094,
#  0.011422042734920979,
#  -0.009814955294132233,
#  0.01751931570470333,
#  -0.019657500088214874,
#  -0.003502138890326023,
#  -0.011470324359834194,
#  -0.03012770600616932,
#  0.01346366386860609,
#  0.009883929044008255,
#  0.009601136669516563,
#  0.004624685738235712,
#  -0.0105598708614707,
#  -0.01451206300407648,
#  0.0009526990470476449,
#  0.01196693442761898,
#  0.016829580068588257,
#  -0.03581113740801811,
#  -0.03972884267568588,
#  0.008849323727190495,
#  -0.013974068686366081,
#  0.04086001217365265,
#  0.017091678455471992,
#  0.0076698740012943745,
#  -0.025837542489171028,
#  -0.015767384320497513,
#  -0.016263995319604874,
#  -0.03589390590786934,
#  -0.011773807927966118,
#  -0.00665251212194562,
#  0.016981322318315506,
#  0.017105473205447197,
#  -0.0019502309150993824,
#  0.0005543759907595813,
#  0.014415500685572624,
#  -0.0005944669246673584,
#  0.013242947869002819,
#  0.0036728486884385347,
#  0.023547615855932236,
#  -0.017284804955124855,
#  -0.01262908149510622,
#  0.021423226222395897,
#  -0.0024451171047985554,
#  0.01424996368587017,
#  0.01045641116797924,
#  -0.0016933039296418428,
#  0.015256979502737522,
#  0.020236879587173462,
#  -0.0251340102404356,
#  -0.0217405054718256,
#  -0.017215831205248833,
#  -0.02673420123755932,
#  -0.018126284703612328,
#  0.0031107133254408836,
#  0.0007819891325198114,
#  0.006373168434947729,
#  -0.03040360100567341,
#  0.01437411643564701,
#  0.02198881097137928,
#  0.015546668320894241,
#  0.0007293967064470053,
#  -0.0015751864993944764,
#  0.02451324835419655,
#  -0.022568190470337868,
#  0.03172789514064789,
#  -0.022333679720759392,
#  -0.003436613827943802,
#  -0.028996536508202553,
#  -0.010925431735813618,
#  -0.042294662445783615,
#  -0.021602557972073555,
#  0.01062194723635912,
#  -0.00585931446403265,
#  0.006514564622193575,
#  0.003224519779905677,
#  0.003993576392531395,
#  0.010325361043214798,
#  -0.001896776375360787,
#  0.0019450578838586807,
#  -0.024596016854047775,
#  0.0013225703733041883,
#  -0.02201640047132969,
#  -0.0016588171711191535,
#  -0.022043989971280098,
#  -0.01789177395403385,
#  -0.005707572679966688,
#  -0.0011044411221519113,
#  -0.004835055209696293,
#  -0.02124389447271824,
#  0.008207868784666061,
#  -0.021381841972470284,
#  -0.01575358957052231,
#  0.00422463845461607,
#  0.006766318343579769,
#  0.029769042506814003,
#  0.022802701219916344,
#  0.02186465822160244,
#  0.05269589647650719,
#  -0.0032210710924118757,
#  -0.00568343186751008,
#  -0.001798488898202777,
#  0.02954832650721073,
#  -0.007400876376777887,
#  0.016539890319108963,
#  0.02587892673909664,
#  -0.0055420356802642345,
#  -0.03517657890915871,
#  0.03741132840514183,
#  -0.02019549533724785,
#  -0.02812746912240982,
#  0.006369719747453928,
#  0.021781889721751213,
#  -0.0018036619294434786,
#  -0.004241881892085075,
#  -0.012097984552383423,
#  -0.00902175810188055,
#  -0.02300962060689926,
#  0.023726947605609894,
#  -0.009642520919442177,
#  0.004993694834411144,
#  -0.0012165233492851257,
#  -0.005811032839119434,
#  -0.014098221436142921,
#  0.020057547837495804,
#  0.01150481030344963,
#  0.019588526338338852,
#  0.002272682962939143,
#  -0.010966815985739231,
#  -0.017133062705397606,
#  -0.03059672750532627,
#  0.012615286745131016,
#  0.011808294802904129,
#  -0.012201445177197456,
#  0.010628844611346722,
#  -0.030182885006070137,
#  0.018857406452298164,
#  0.007007726468145847,
#  0.028968947008252144,
#  0.010304668918251991,
#  0.015243184752762318,
#  0.010987508110702038,
#  0.021478405222296715,
#  -0.008890707977116108,
#  -0.012532518245279789,
#  -0.01619502156972885,
#  -0.019905805587768555,
#  -0.010897842235863209,
#  -0.007352594751864672,
#  0.0017200312577188015,
#  -0.016512300819158554,
#  -0.005035079084336758,
#  -0.032307274639606476,
#  0.019174683839082718,
#  0.027437731623649597,
#  -0.014236168935894966,
#  0.01531215850263834,
#  -0.009670110419392586,
#  -0.021947426721453667,
#  0.008283739909529686,
#  -0.015077647753059864,
#  0.014801752753555775,
#  -0.017712442204356194,
#  -0.02580995298922062,
#  -0.025120215490460396,
#  0.017905568704009056,
#  0.006155901588499546,
#  -0.012325597926974297,
#  -0.013574020937085152,
#  0.00565239368006587,
#  0.002865856746211648,
#  -0.016953732818365097,
#  -0.005145437084138393,
#  0.004110831767320633,
#  -0.03200379014015198,
#  0.0035159336403012276,
#  -0.00040996234747581184,
#  -0.007890589535236359,
#  -0.02014031633734703,
#  0.011815192177891731,
#  -0.01640194281935692,
#  -0.02498226799070835,
#  0.0039487434551119804,
#  0.002512366510927677,
#  0.012511826120316982,
#  -0.03724579140543938,
#  0.006852535530924797,
#  0.0382390096783638,
#  -0.005200616084039211,
#  0.004472943488508463,
#  -0.00504197645932436,
#  -0.01954714208841324,
#  0.023078594356775284,
#  -0.009821852669119835,
#  -0.024568427354097366,
#  0.01662265881896019,
#  -0.026720406487584114,
#  0.00927006360143423,
#  0.0023226889315992594,
#  -0.01406373456120491,
#  0.009890826418995857,
#  -0.03090021200478077,
#  -0.0017441720701754093,
#  0.029769042506814003,
#  0.0019071224378421903,
#  -0.011035789735615253,
#  -0.00352283101528883,
#  -0.020774874836206436,
#  -0.01451206300407648,
#  -0.01652609556913376,
#  0.009525265544652939,
#  0.00968390516936779,
#  0.004835055209696293,
#  0.00780092366039753,
#  0.02365797385573387,
#  0.02960350550711155,
#  0.0014889694284647703,
#  0.0008488073945045471,
#  -0.0017415855545550585,
#  -0.016457121819257736,
#  -0.015863947570323944,
#  -0.04927480220794678,
#  -0.009242474101483822,
#  -0.016015689820051193,
#  0.016057074069976807,
#  0.017905568704009056,
#  -0.009856339544057846,
#  -0.009014860726892948,
#  0.002450290136039257,
#  -0.020650722086429596,
#  0.006490423809736967,
#  0.004197048954665661,
#  0.005866211839020252,
#  0.017229625955224037,
#  0.01127030048519373,
#  -0.014346526935696602,
#  0.016360558569431305,
#  -0.01687096431851387,
#  0.017602084204554558,
#  -0.026761790737509727,
#  -0.006931855343282223,
#  -0.021105946972966194,
#  -0.003852180438116193,
#  0.002948625013232231,
#  0.002148530213162303,
#  -0.02849992737174034,
#  0.007373286876827478,
#  0.011953139677643776,
#  0.014208579435944557,
#  0.022623369470238686,
#  0.0004935929318889976,
#  -0.012539415620267391,
#  -0.015215595252811909,
#  0.01998857408761978,
#  0.01309120561927557,
#  0.01647091656923294,
#  0.009132116101682186,
#  0.007766436785459518,
#  -0.027961932122707367,
#  -0.0043418933637440205,
#  0.0076698740012943745,
#  0.0021261137444525957,
#  -0.007883692160248756,
#  -0.015325953252613544,
#  0.011222018860280514,
#  0.005214410834014416,
#  -0.00562135549262166,
#  0.018788432702422142,
#  0.0023606244940310717,
#  0.0042453305795788765,
#  -0.0027158388402312994,
#  0.035976674407720566,
#  -0.02223711647093296,
#  -0.025644415989518166,
#  0.00598346721380949,
#  0.020623132586479187,
#  -0.008366508409380913,
#  0.005414434242993593,
#  0.0022175039630383253,
#  0.009159705601632595,
#  -0.004838503897190094,
#  0.01751931570470333,
#  -0.02785157412290573,
#  0.007725053001195192,
#  -0.024471864104270935,
#  -0.006031748838722706,
#  -0.012794618494808674,
#  -0.01647091656923294,
#  -0.03170030564069748,
#  0.0040108198300004005,
#  -0.025451289489865303,
#  0.0023295863065868616,
#  0.034707557410001755,
#  -0.026292769238352776,
#  0.009532162919640541,
#  -0.0311485156416893,
#  -0.00786300003528595,
#  -0.012284213677048683,
#  -0.02278890646994114,
#  0.0191195048391819,
#  -0.0016320898430421948,
#  -0.019009146839380264,
#  0.009849442169070244,
#  -0.018884995952248573,
#  -0.020485185086727142,
#  -0.007607797626405954,
#  0.021133536472916603,
#  -0.02540990523993969,
#  0.026485895738005638,
#  0.22093650698661804,
#  -0.020774874836206436,
#  0.0032210710924118757,
#  0.022030195221304893,
#  0.022347474470734596,
#  0.028196442872285843,
#  0.020554158836603165,
#  0.01914709433913231,
#  0.012132471427321434,
#  0.02071969583630562,
#  0.015477695502340794,
#  -0.014049939811229706,
#  0.0010889220284298062,
#  -0.008063023909926414,
#  0.015256979502737522,
#  -0.038652852177619934,
#  -0.042018767446279526,
#  -0.027589473873376846,
#  -0.005038527771830559,
#  -0.009394216351211071,
#  0.03150717914104462,
#  -0.0033659159671515226,
#  0.006586987059563398,
#  -0.018912585452198982,
#  0.007807821035385132,
#  0.009276960976421833,
#  -0.010304668918251991,
#  -0.0015631160931661725,
#  0.021174920722842216,
#  0.007649181876331568,
#  -0.0012147990055382252,
#  0.006873227655887604,
#  -0.006231772713363171,
#  0.016181226819753647,
#  -0.0014303418574854732,
#  0.006162798963487148,
#  0.013953376561403275,
#  -0.02910689450800419,
#  0.010346053168177605,
#  0.004034960642457008,
#  0.02510642074048519,
#  -0.00507301464676857,
#  0.007628489751368761,
#  -0.01789177395403385,
#  0.005724816117435694,
#  0.0403909906744957,
#  ...]

# %%
df.to_csv('fine_food_reviews_with_embeddings_1k_2.csv')

# %%
# read csv into df

df = pd.read_csv('fine_food_reviews_with_embeddings_1k_2.csv')

# %%
df["ada_search"] = df.ada_search.apply(np.array)

# %%
embedding = get_embedding(
        "what is product",
        engine="text-embedding-ada-002"
    )
similarityvector = np.dot(np.array(embedding), np.array(df2["embeddings"]))

# %%
df2
# Out:
#                                                  text  \
# 15                          past-speaking-engagements
# 17  four-pillars-of-world-class-product-documentation
# 30  lack-of-courage-and-fear-of-failure-keep-the-f...
# 32  25-most-common-questions-asked-in-a-tech-produ...
# 76                     six-types-of-product-discovery
#
#                                                 links  \
# 15  https://www.medium.com/@sergioschuler/past-spe...
# 17  https://www.medium.com/@sebscholl/four-pillars...
# 30  https://www.medium.com/serious-scrum/lack-of-c...
# 32  https://www.medium.com/@smohajer85/25-most-com...
# 76  https://www.medium.com/@susan_ski/six-types-of...
#
#                                               content  content_length  \
# 15  Past speaking engagements - Sérgio Schüler - M...            1925
# 17  Four Pillars of World-Class Product Documentat...            1464
# 30  Lack of Courage And Fear of Failure Keep the F...            1626
# 32  25 most common questions asked in a tech produ...             996
# 76  Six Types of Product Discovery. “You need to d...            1649
#
#                                              combined  \
# 15  Title: past-speaking-engagements; Content: Pas...
# 17  Title: four-pillars-of-world-class-product-doc...
# 30  Title: lack-of-courage-and-fear-of-failure-kee...
# 32  Title: 25-most-common-questions-asked-in-a-tec...
# 76  Title: six-types-of-product-discovery; Content...
#
#                                            embeddings
# 15  [-0.01302818488329649, -0.0026764797512441874,...
# 17  [0.02161411941051483, 0.038200464099645615, 0....
# 30  [-0.02281850576400757, -0.007446258328855038, ...
# 32  [0.013337370939552784, -0.013675819151103497, ...
# 76  [0.0038728078361600637, 0.020918523892760277, ...

# %%
df2["similarities2"] = df2.embeddings.apply(lambda x: np.dot(np.array(embedding), np.array(x)))

# %%
df2 = df2.sort_values("similarities2", ascending=False).head(10)

# %%
COMPLETIONS_MODEL = "text-davinci-002"

prompt = """Answer the question as truthfully as possible, and if you're unsure of the answer, say "Sorry, I don't know".

Q: Who won the 2020 Summer Olympics men's high jump?
A:"""

openai.Completion.create(
    prompt=prompt,
    temperature=0,
    max_tokens=300,
    top_p=1,
    frequency_penalty=0,
    presence_penalty=0,
    model=COMPLETIONS_MODEL
)["choices"][0]["text"].strip(" \n")
# Out:
# "Sorry, I don't know."

# %%
# reset row index of df2

df2 = df2.reset_index(drop=True)

# %%
df2
# Out:
#                                                 text  \
# 0  four-pillars-of-world-class-product-documentation
# 1                     six-types-of-product-discovery
# 2  25-most-common-questions-asked-in-a-tech-produ...
# 3                          past-speaking-engagements
# 4  lack-of-courage-and-fear-of-failure-keep-the-f...
#
#                                                links  \
# 0  https://www.medium.com/@sebscholl/four-pillars...
# 1  https://www.medium.com/@susan_ski/six-types-of...
# 2  https://www.medium.com/@smohajer85/25-most-com...
# 3  https://www.medium.com/@sergioschuler/past-spe...
# 4  https://www.medium.com/serious-scrum/lack-of-c...
#
#                                              content  content_length  \
# 0  Four Pillars of World-Class Product Documentat...            1464
# 1  Six Types of Product Discovery. “You need to d...            1649
# 2  25 most common questions asked in a tech produ...             996
# 3  Past speaking engagements - Sérgio Schüler - M...            1925
# 4  Lack of Courage And Fear of Failure Keep the F...            1626
#
#                                             combined  \
# 0  Title: four-pillars-of-world-class-product-doc...
# 1  Title: six-types-of-product-discovery; Content...
# 2  Title: 25-most-common-questions-asked-in-a-tec...
# 3  Title: past-speaking-engagements; Content: Pas...
# 4  Title: lack-of-courage-and-fear-of-failure-kee...
#
#                                           embeddings  similarities2
# 0  [0.02161411941051483, 0.038200464099645615, 0....       0.775472
# 1  [0.0038728078361600637, 0.020918523892760277, ...       0.774522
# 2  [0.013337370939552784, -0.013675819151103497, ...       0.753723
# 3  [-0.01302818488329649, -0.0026764797512441874,...       0.732899
# 4  [-0.02281850576400757, -0.007446258328855038, ...       0.717026

# %%
# make the prompt the content from the first 2 rows of df2

prompt = df2.content[0] + df2.content[1] + df2.content[2] + df2.content[3]

prompt2 = """  Answer the question as truthfully as possible. if you don't say "Sorry, I don't know".

Q: what is product management?
A:"""

prompt = prompt + prompt2

openai.Completion.create(
    prompt=prompt,
    temperature=0,
    max_tokens=300,
    top_p=1,
    frequency_penalty=0,
    presence_penalty=0,
    model=COMPLETIONS_MODEL
)["choices"][0]["text"].strip(" \n")
# Out:
# 'Product management is the process of planning, developing, and launching products. It involves defining the product strategy, roadmap, and requirements; conducting market research; and managing the product lifecycle.'

# %%
from openai.embeddings_utils import get_embedding, cosine_similarity

# search through the reviews for a specific product
def search_reviews(df, product_description, n=3, pprint=True):
    embedding = get_embedding(
        product_description,
        engine="text-embedding-ada-002"
    )
    df["similarities"] = df.ada_search.apply(lambda x: cosine_similarity(x, embedding))

    res = (
        df.sort_values("similarities", ascending=False)
        .head(n)
        .combined.str.replace("Title: ", "")
        .str.replace("; Content:", ": ")
    )
    if pprint:
        for r in res:
            print(r[:200])
            print()
    return res


res = search_reviews(df, "which coffee is best?", n=10)

# %%
import openai
from openai.embeddings_utils import get_embedding

# %%
stuff = "delicious beans delicious beansdelicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans delicious beans "
stuff2 = stuff*10
get_embedding(stuff2, engine="text-embedding-ada-002")

# %%
len(stuff2)
